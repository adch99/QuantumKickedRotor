# %%
import quantum_kicked_rotor as rotor
import scipy.sparse.linalg as splinalg
import numpy as 
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

# %%
avgs, vars, p = rotor.run()
# Out:
# Starting cycle no 0...
# Starting cycle no 1...
# Starting cycle no 2...
# Starting cycle no 3...
# Starting cycle no 4...
# Starting cycle no 5...
# Starting cycle no 6...
# Starting cycle no 7...
# Starting cycle no 8...
# Starting cycle no 9...
# Starting cycle no 10...
# Starting cycle no 11...
# Starting cycle no 12...
# Starting cycle no 13...
# Starting cycle no 14...
# Starting cycle no 15...
# Starting cycle no 16...
# Starting cycle no 17...
# Starting cycle no 18...
# Starting cycle no 19...
# Starting cycle no 20...
# Starting cycle no 21...
# Starting cycle no 22...
# Starting cycle no 23...
# Starting cycle no 24...
# Starting cycle no 25...
# Starting cycle no 26...
# Starting cycle no 27...
# Starting cycle no 28...
# Starting cycle no 29...
# Starting cycle no 30...
# Starting cycle no 31...
# Starting cycle no 32...
# Starting cycle no 33...
# Starting cycle no 34...
# Starting cycle no 35...
# Starting cycle no 36...
# Starting cycle no 37...
# ...

# %%
rotor.plot(avgs, vars, p)

# %%
F = rotor.floquetOperator()
rotor.visualizeFloquetEigs(F)
# Out:
# [ 0.6764717 +0.73646855j  0.6737044 +0.7390009j  -0.7375566 +0.6752851j
#  ...  0.9220255 +0.3710873j   0.9618315 +0.2736425j
#  -0.20255175+0.97927153j]
